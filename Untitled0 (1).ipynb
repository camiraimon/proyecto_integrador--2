# %%
# prompt: armar una dataframe e al menos 100 filas con dato random con apellido y nombre, nro_dni, materia de educacion de nivel secundario de la argentina que contenga las siguientes columnas: materia escolar, nota de 1er trimestre, nota de 2do trimestre, nota de 3 trimestre, faltas a clases

import pandas as pd
import numpy as np
import random

# Define possible subjects
subjects = ['Matemática', 'Lengua y Literatura', 'Historia', 'Geografía', 'Ciencias Naturales', 'Educación Física', 'Inglés', 'Física', 'Química', 'Biología', 'Arte', 'Música']

# Create an empty list to store data
data = []

# Generate 100 random entries
for i in range(100):
  # Generate random names and surnames (you can improve this)
  first_name = f"Nombre_{i}"
  last_name = f"Apellido_{i}"

  # Generate random DNI
  dni = random.randint(10000000, 99999999)

  # Select random subject
  subject = random.choice(subjects)

  # Generate random grades and absences
  q1_grade = random.randint(1, 10)
  q2_grade = random.randint(1, 10)
  q3_grade = random.randint(1, 10)
  absences = random.randint(0, 15)

  # Append to the data list
  data.append([first_name, last_name, dni, subject, q1_grade, q2_grade, q3_grade, absences])

# Create the DataFrame
df = pd.DataFrame(data, columns=['Nombre', 'Apellido', 'Nro_DNI', 'Materia', 'Nota_1er_Trimestre', 'Nota_2do_Trimestre', 'Nota_3er_Trimestre', 'Faltas'])

# Display the DataFrame (optional)
df
# Out:
#        Nombre     Apellido   Nro_DNI             Materia  Nota_1er_Trimestre  \
# 0    Nombre_0   Apellido_0  12723161           Geografía                  10
# 1    Nombre_1   Apellido_1  36031051              Inglés                   7
# 2    Nombre_2   Apellido_2  72350915              Música                   8
# 3    Nombre_3   Apellido_3  70450442            Historia                   2
# 4    Nombre_4   Apellido_4  28574392          Matemática                   5
# ..        ...          ...       ...                 ...                 ...
# 95  Nombre_95  Apellido_95  89625209             Química                   5
# 96  Nombre_96  Apellido_96  33950133              Física                   2
# 97  Nombre_97  Apellido_97  96514636            Historia                   8
# 98  Nombre_98  Apellido_98  96982268  Ciencias Naturales                   8
# 99  Nombre_99  Apellido_99  16870910                Arte                   7
#
# ...
